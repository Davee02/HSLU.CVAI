# %%
from socket_utils import SocketClient

# %%
host = "192.168.1.218"
port = 5050

client = SocketClient(host, port)
client.connect()
# Out:
# Connected to 192.168.1.218:5050

# %%
client.send("change_volume 5")
# Out:
# Sent command: change_volume 5

# %%
client.send("change_volume -5")
# Out:
# Sent command: change_volume -5

# %%
client.send("play_pause")
# Out:
# Error sending command: [Errno 32] Broken pipe

# %%
client.close()
# Out:
# Connection closed
