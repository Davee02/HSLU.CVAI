# %%
from socket_utils import send_command

# %%
host = "192.168.1.218"
port = 5050

# %%
send_command("change_volume 5", host, port)
# Out:
# True

# %%
send_command("change_volume -5", host, port)
# Out:
# True

# %%
send_command("play_pause", host, port)
# Out:
# True
